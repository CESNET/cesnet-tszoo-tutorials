# %% [markdown]
# # Choosing data for TimeBasedCesnetDataset

# %% [markdown]
# ### Import

# %%
import logging
from datetime import datetime

from cesnet_tszoo.utils.enums import AgreggationType, SourceType, TimeFormat, DatasetType
from cesnet_tszoo.datasets import CESNET_TimeSeries24
from cesnet_tszoo.configs import TimeBasedConfig # Time based dataset MUST use TimeBasedConfig

# %% [markdown]
# ### Setting logger

# %%
logging.basicConfig(
    level=logging.INFO,
    format="[%(asctime)s][%(name)s][%(levelname)s] - %(message)s")

# %% [markdown]
# ### Preparing dataset

# %%
time_based_dataset = CESNET_TimeSeries24.get_dataset(data_root="/some_directory/", source_type=SourceType.INSTITUTION_SUBNETS, aggregation=AgreggationType.AGG_1_HOUR, dataset_type=DatasetType.TIME_BASED, display_details=True)
# Out:
# [2025-11-14 18:43:40,340][cesnet_dataset][INFO] - Dataset is time-based. Use cesnet_tszoo.configs.TimeBasedConfig
# Dataset details:
#
#     AgreggationType.AGG_1_HOUR
#         Time indices: range(0, 6717)
#         Datetime: (datetime.datetime(2023, 10, 9, 0, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 14, 21, 0, tzinfo=datetime.timezone.utc))
#
#     SourceType.INSTITUTION_SUBNETS
#         Time series indices: [0 1 2 3 4 ... 543 544 545 546 547], Length=548; use 'get_available_ts_indices' for full list
#         Features with default values: {'n_flows': 0, 'n_packets': 0, 'n_bytes': 0, 'tcp_udp_ratio_packets': 0.5, 'tcp_udp_ratio_bytes': 0.5, 'dir_ratio_packets': 0.5, 'dir_ratio_bytes': 0.5, 'avg_duration': 0, 'avg_ttl': 0, 'sum_n_dest_asn': 0, 'avg_n_dest_asn': 0, 'std_n_dest_asn': 0, 'sum_n_dest_ports': 0, 'avg_n_dest_ports': 0, 'std_n_dest_ports': 0, 'sum_n_dest_ip': 0, 'avg_n_dest_ip': 0, 'std_n_dest_ip': 0}
#
# ...

# %% [markdown]
# ### Selecting which time series to load

# %% [markdown]
# - Sets time series that will be used for train/val/test/all sets

# %% [markdown]
# #### Setting ts_ids with number of time series

# %% [markdown]
# - Sets time series used in sets with number.
# - Count must be greater than zero.
# - Total sum of time series in `ts_ids` must be smaller than number of time series in dataset.
# - Is affected by `random_state`.
#     - When `random_state` is set, `ts_ids` will contain same time series on repeated tries.

# %%
config = TimeBasedConfig(ts_ids=54, random_state = 111)
time_based_dataset.set_dataset_config_and_initialize(config, display_config_details="text", workers=0)
# Out:
# [2025-11-14 18:43:40,346][time_config][INFO] - Quick validation succeeded.
# [2025-11-14 18:43:40,347][time_config][INFO] - Using all times for all_time_period because train_time_period, val_time_period, and test_time_period are all set to None.
# [2025-11-14 18:43:40,348][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# [2025-11-14 18:43:40,348][cesnet_dataset][INFO] - Starting fitting cycle 1/1.
# 100%|██████████| 54/54 [00:00<00:00, 608.14it/s]
# [2025-11-14 18:43:40,448][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_1_HOUR
#     Source: SourceType.INSTITUTION_SUBNETS
#
#     Time series
#         Time series IDS: [ 54 226 135 160 236 ...   7 118 322 275  86], Length=54
#     Time periods
#         Train time periods: None
#         Val time periods: None
#         Test time periods: None
# ...

# %% [markdown]
# #### Setting ts_ids with percentage of time series in dataset

# %% [markdown]
# - Sets time series used in sets with percentage of time series in dataset.
# - Percentage must be greater than 0.
# - Percentage must be smaller than 1.0.
# - Is affected by `random_state`.
#     - When `random_state` is set, `ts_ids` will contain same time series on repeated tries.

# %%
config = TimeBasedConfig(ts_ids=0.1, random_state = 111)
time_based_dataset.set_dataset_config_and_initialize(config, display_config_details="text", workers=0)
# Out:
# [2025-11-14 18:43:40,454][time_config][INFO] - Quick validation succeeded.
# [2025-11-14 18:43:40,455][time_config][INFO] - Using all times for all_time_period because train_time_period, val_time_period, and test_time_period are all set to None.
# [2025-11-14 18:43:40,455][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# [2025-11-14 18:43:40,455][cesnet_dataset][INFO] - Starting fitting cycle 1/1.
# 100%|██████████| 54/54 [00:00<00:00, 590.51it/s]
# [2025-11-14 18:43:40,558][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_1_HOUR
#     Source: SourceType.INSTITUTION_SUBNETS
#
#     Time series
#         Time series IDS: [ 54 226 135 160 236 ...   7 118 322 275  86], Length=54
#     Time periods
#         Train time periods: None
#         Val time periods: None
#         Test time periods: None
# ...

# %% [markdown]
# #### Setting ts_ids with specific time series indices

# %%
config = TimeBasedConfig(ts_ids=[0,1,2,3,4,5])
time_based_dataset.set_dataset_config_and_initialize(config, display_config_details="text", workers=0)
# Out:
# [2025-11-14 18:43:40,564][time_config][INFO] - Quick validation succeeded.
# [2025-11-14 18:43:40,565][time_config][INFO] - Using all times for all_time_period because train_time_period, val_time_period, and test_time_period are all set to None.
# [2025-11-14 18:43:40,565][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# [2025-11-14 18:43:40,566][cesnet_dataset][INFO] - Starting fitting cycle 1/1.
# 100%|██████████| 6/6 [00:00<00:00, 666.43it/s]
# [2025-11-14 18:43:40,582][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_1_HOUR
#     Source: SourceType.INSTITUTION_SUBNETS
#
#     Time series
#         Time series IDS: [0 1 2 3 4 5], Length=6
#     Time periods
#         Train time periods: None
#         Val time periods: None
#         Test time periods: None
#         All time periods: range(0, 6718)
#     Features
# ...

# %% [markdown]
# ### Creating train/val/test sets

# %% [markdown]
# - Sets time period in set for every time series in `ts_ids`
# - You can leave any set value set as None.
# - Can use `nan_threshold` to set how many nan values will be tolerated.
#     - `nan_threshold` = 1.0, means that time series can be completely empty.
#     - is applied after sets.
#     - Is checked seperately for every set.

# %% [markdown]
# #### Setting sets with time indices

# %% [markdown]
# - Sets sets as range of time indices.
# - Sets must follow these rules:
#     - Used time periods must be connected.
#     - Sets can share subset of times.
#     - start of `train_time_period` < start of `val_time_period` < start of `test_time_period`.

# %%
config = TimeBasedConfig(ts_ids=54, train_time_period=range(0, 2000), val_time_period=range(2000, 4000), test_time_period=range(4000, 5000), random_state=111)
time_based_dataset.set_dataset_config_and_initialize(config, display_config_details="text", workers=0)
# Out:
# [2025-11-14 18:43:40,587][time_config][INFO] - Quick validation succeeded.
# [2025-11-14 18:43:40,652][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# [2025-11-14 18:43:40,652][cesnet_dataset][INFO] - Starting fitting cycle 1/1.
# 100%|██████████| 54/54 [00:00<00:00, 884.34it/s]
# [2025-11-14 18:43:40,724][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_1_HOUR
#     Source: SourceType.INSTITUTION_SUBNETS
#
#     Time series
#         Time series IDS: [ 54 226 135 160 236 ...   7 118 322 275  86], Length=54
#     Time periods
#         Train time periods: range(0, 2000)
#         Val time periods: range(2000, 4000)
#         Test time periods: range(4000, 5000)
#         All time periods: range(0, 5000)
#     Features
# ...

# %% [markdown]
# #### Setting sets with datetime

# %% [markdown]
# - Sets sets with tuple of datetime objects.
# - Datetime objects are expected to be of UTC.
# - Sets must follow these rules:
#     - Used time periods must be connected.
#     - Sets can share subset of times.
#     - start of `train_time_period` < start of `val_time_period` < start of `test_time_period`.

# %%
config = TimeBasedConfig(ts_ids=54, train_time_period=(datetime(2023, 10, 9, 0), datetime(2023, 11, 9, 23)), val_time_period=(datetime(2023, 11, 9, 23), datetime(2023, 12, 9, 23)), test_time_period=(datetime(2023, 12, 9, 23), datetime(2023, 12, 25, 23)), 
                         random_state=111)
time_based_dataset.set_dataset_config_and_initialize(config, display_config_details="text", workers=0)
# Out:
# [2025-11-14 18:43:40,730][time_config][INFO] - Quick validation succeeded.
# [2025-11-14 18:43:40,732][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# [2025-11-14 18:43:40,732][cesnet_dataset][INFO] - Starting fitting cycle 1/1.
# 100%|██████████| 54/54 [00:00<00:00, 1400.36it/s]
# [2025-11-14 18:43:40,780][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_1_HOUR
#     Source: SourceType.INSTITUTION_SUBNETS
#
#     Time series
#         Time series IDS: [ 54 226 135 160 236 ...   7 118 322 275  86], Length=54
#     Time periods
#         Train time periods: range(0, 767)
#         Val time periods: range(767, 1487)
#         Test time periods: range(1487, 1871)
#         All time periods: range(0, 1871)
#     Features
# ...

# %% [markdown]
# #### Setting sets with percentage

# %% [markdown]
# - Sets sets a percentage of whole time period from dataset.
# - Always starts from first time.
# - Must be: 0 < sum of percentages of set time periods <= 1.

# %%
config = TimeBasedConfig(ts_ids=54, train_time_period=0.5, val_time_period=0.3, test_time_period=0.2, random_state=111)
time_based_dataset.set_dataset_config_and_initialize(config, display_config_details="text", workers=0)
# Out:
# [2025-11-14 18:43:40,787][time_config][INFO] - Quick validation succeeded.
# [2025-11-14 18:43:40,803][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# [2025-11-14 18:43:40,803][cesnet_dataset][INFO] - Starting fitting cycle 1/1.
# 100%|██████████| 54/54 [00:00<00:00, 650.37it/s]
# [2025-11-14 18:43:40,896][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_1_HOUR
#     Source: SourceType.INSTITUTION_SUBNETS
#
#     Time series
#         Time series IDS: [ 54 226 135 160 236 ...   7 118 322 275  86], Length=54
#     Time periods
#         Train time periods: range(0, 3359)
#         Val time periods: range(3359, 5374)
#         Test time periods: range(5374, 6717)
#         All time periods: range(0, 6717)
#     Features
# ...

# %% [markdown]
# ### Selecting features

# %% [markdown]
# - Affects which features will be returned when loading data.
# - Setting `include_time` as True will add time to features that return when loading data.
# - Setting `include_ts_id` as True will add time series id to features that return when loading data.

# %% [markdown]
# #### Setting features to take as "all"

# %%
config = TimeBasedConfig(ts_ids=54, train_time_period=0.5, val_time_period=0.3, test_time_period=0.2, features_to_take="all", random_state=111)
time_based_dataset.set_dataset_config_and_initialize(config, display_config_details="text", workers=0)
# Out:
# [2025-11-14 18:43:40,902][time_config][INFO] - Quick validation succeeded.
# [2025-11-14 18:43:40,919][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# [2025-11-14 18:43:40,919][cesnet_dataset][INFO] - Starting fitting cycle 1/1.
# 100%|██████████| 54/54 [00:00<00:00, 639.60it/s]
# [2025-11-14 18:43:41,013][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_1_HOUR
#     Source: SourceType.INSTITUTION_SUBNETS
#
#     Time series
#         Time series IDS: [ 54 226 135 160 236 ...   7 118 322 275  86], Length=54
#     Time periods
#         Train time periods: range(0, 3359)
#         Val time periods: range(3359, 5374)
#         Test time periods: range(5374, 6717)
#         All time periods: range(0, 6717)
#     Features
# ...

# %% [markdown]
# #### Setting features via list

# %%
config = TimeBasedConfig(ts_ids=54, train_time_period=0.5, val_time_period=0.3, test_time_period=0.2, features_to_take=["n_flows", "n_packets"], random_state=111)
time_based_dataset.set_dataset_config_and_initialize(config, display_config_details="text", workers=0)
# Out:
# [2025-11-14 18:43:41,020][time_config][INFO] - Quick validation succeeded.
# [2025-11-14 18:43:41,035][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# [2025-11-14 18:43:41,036][cesnet_dataset][INFO] - Starting fitting cycle 1/1.
# 100%|██████████| 54/54 [00:00<00:00, 949.71it/s]
# [2025-11-14 18:43:41,104][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_1_HOUR
#     Source: SourceType.INSTITUTION_SUBNETS
#
#     Time series
#         Time series IDS: [ 54 226 135 160 236 ...   7 118 322 275  86], Length=54
#     Time periods
#         Train time periods: range(0, 3359)
#         Val time periods: range(3359, 5374)
#         Test time periods: range(5374, 6717)
#         All time periods: range(0, 6717)
#     Features
#         Taken features: ['n_flows', 'n_packets']
#         Default values: [0. 0.]
# ...

# %% [markdown]
# #### Including time and time series id

# %%
config = TimeBasedConfig(ts_ids=54, train_time_period=0.5, val_time_period=0.3, test_time_period=0.2, features_to_take=["n_flows", "n_packets"], include_time=True, include_ts_id=True, time_format=TimeFormat.ID_TIME, random_state=111)
time_based_dataset.set_dataset_config_and_initialize(config, display_config_details="text", workers=0)
# Out:
# [2025-11-14 18:43:41,109][time_config][INFO] - Quick validation succeeded.
# [2025-11-14 18:43:41,125][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# [2025-11-14 18:43:41,126][cesnet_dataset][INFO] - Starting fitting cycle 1/1.
# 100%|██████████| 54/54 [00:00<00:00, 963.17it/s]
# [2025-11-14 18:43:41,191][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_1_HOUR
#     Source: SourceType.INSTITUTION_SUBNETS
#
#     Time series
#         Time series IDS: [ 54 226 135 160 236 ...   7 118 322 275  86], Length=54
#     Time periods
#         Train time periods: range(0, 3359)
#         Val time periods: range(3359, 5374)
#         Test time periods: range(5374, 6717)
#         All time periods: range(0, 6717)
#     Features
#         Taken features: ['n_flows', 'n_packets']
#         Default values: [0. 0.]
# ...

# %% [markdown]
# ### Selecting all set

# %% [markdown]
# - Contains time series from `ts_ids`.

# %% [markdown]
# #### All set when other sets are None

# %% [markdown]
# - All set will contain whole time period of dataset.

# %%
config = TimeBasedConfig(ts_ids=54, train_time_period=None, val_time_period=None, test_time_period=None, random_state=111)
time_based_dataset.set_dataset_config_and_initialize(config, display_config_details="text", workers=0)
# Out:
# [2025-11-14 18:43:41,197][time_config][INFO] - Quick validation succeeded.
# [2025-11-14 18:43:41,198][time_config][INFO] - Using all times for all_time_period because train_time_period, val_time_period, and test_time_period are all set to None.
# [2025-11-14 18:43:41,199][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# [2025-11-14 18:43:41,199][cesnet_dataset][INFO] - Starting fitting cycle 1/1.
# 100%|██████████| 54/54 [00:00<00:00, 653.65it/s]
# [2025-11-14 18:43:41,292][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_1_HOUR
#     Source: SourceType.INSTITUTION_SUBNETS
#
#     Time series
#         Time series IDS: [ 54 226 135 160 236 ...   7 118 322 275  86], Length=54
#     Time periods
#         Train time periods: None
#         Val time periods: None
#         Test time periods: None
# ...

# %% [markdown]
# #### All set when at least one other set is not None

# %% [markdown]
# - All set will contain total time period of train + val + test.

# %%
config = TimeBasedConfig(ts_ids=54, train_time_period=0.5, val_time_period=0.3, test_time_period=0.2, random_state=111)
time_based_dataset.set_dataset_config_and_initialize(config, display_config_details="text", workers=0)
# Out:
# [2025-11-14 18:43:41,296][time_config][INFO] - Quick validation succeeded.
# [2025-11-14 18:43:41,312][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# [2025-11-14 18:43:41,312][cesnet_dataset][INFO] - Starting fitting cycle 1/1.
# 100%|██████████| 54/54 [00:00<00:00, 612.83it/s]
# [2025-11-14 18:43:41,410][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_1_HOUR
#     Source: SourceType.INSTITUTION_SUBNETS
#
#     Time series
#         Time series IDS: [ 54 226 135 160 236 ...   7 118 322 275  86], Length=54
#     Time periods
#         Train time periods: range(0, 3359)
#         Val time periods: range(3359, 5374)
#         Test time periods: range(5374, 6717)
#         All time periods: range(0, 6717)
#     Features
# ...
